# %% [markdown]
# # Final Exercise - Putting it All Together
#
# In this last exercise, you'll write a full ETL pipeline for the GDP data. That means you'll extract the World Bank data, transform the data, and load the data all in one go. In other words, you'll want one Python script that can do the entire process.
#
# Why would you want to do this? Imagine working for a company that creates new data every day. As new data comes in, you'll want to write software that periodically and automatically extracts, transforms, and loads the data.
#
# To give you a sense for what this is like, you'll extract the GDP data one line at a time. You'll then transform that line of data and load the results into a SQLite database. The code in this exercise is somewhat tricky.
#
# Here is an explanation of how this Jupyter notebook is organized:
# 1. The first cell connects to a SQLite database called worldbank.db and creates a table to hold the gdp data. You do not need to do anything in this code cell other than executing the cell.
# 2. The second cell has a function called extract_line(). You don't need to do anything in this code cell either besides executing the cell. This function is a [Python generator](https://wiki.python.org/moin/Generators). You don't need to understand how this works in order to complete the exercise. Essentially, a generator is like a regular function except instead of a return statement, a generator has a yield statement. Generators allow you to use functions in a for loop. In essence, this function will allow you to read in a data file one line at a time, run a transformation on that row of data, and then move on to the next row in the file.
# 3. The third cell contains a function called transform_indicator_data(). This function receives a line from the csv file and transforms the data in preparation for a load step.
# 4. The fourth cell contains a function called load_indicator_data(), which loads the trasnformed data into the gdp table in the worldbank.db database.
# 5. The fifth cell runs the ETL pipeilne
# 6. The sixth cell runs a query against the database to make sure everything worked correctly.
#
# You'll need to modify the third and fourth cells.

# %%
# run this cell to create a database and a table, called gdp, to hold the gdp data
# You do not need to change anything in this code cell

import sqlite3

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# drop the test table in case it already exists
cur.execute("DROP TABLE IF EXISTS gdp")

# create the test table including project_id as a primary key
cur.execute("CREATE TABLE gdp (countryname TEXT, countrycode TEXT, year INTEGER, gdp REAL, PRIMARY KEY (countrycode, year));")

conn.commit()
conn.close()

# %%
# Generator for reading in one line at a time
# generators are useful for data sets that are too large to fit in RAM
# You do not need to change anything in this code cell
def extract_lines(file):
    while True:
        line = file.readline()
        if not line:
            break
        yield line

# %%
# TODO: fill out the code wherever you find a TODO in this cell

import pandas as pd
import numpy as np
import sqlite3

# transform the indicator data
def transform_indicator_data(data, colnames):
    
    # get rid of quote marks
    for i, datum in enumerate(data):
        data[i] = datum.replace('"','')
    
    country = data[0]
    
    # filter out values that are not countries
    non_countries = ['World',
     'High income',
     'OECD members',
     'Post-demographic dividend',
     'IDA & IBRD total',
     'Low & middle income',
     'Middle income',
     'IBRD only',
     'East Asia & Pacific',
     'Europe & Central Asia',
     'North America',
     'Upper middle income',
     'Late-demographic dividend',
     'European Union',
     'East Asia & Pacific (excluding high income)',
     'East Asia & Pacific (IDA & IBRD countries)',
     'Euro area',
     'Early-demographic dividend',
     'Lower middle income',
     'Latin America & Caribbean',
     'Latin America & the Caribbean (IDA & IBRD countries)',
     'Latin America & Caribbean (excluding high income)',
     'Europe & Central Asia (IDA & IBRD countries)',
     'Middle East & North Africa',
     'Europe & Central Asia (excluding high income)',
     'South Asia (IDA & IBRD)',
     'South Asia',
     'Arab World',
     'IDA total',
     'Sub-Saharan Africa',
     'Sub-Saharan Africa (IDA & IBRD countries)',
     'Sub-Saharan Africa (excluding high income)',
     'Middle East & North Africa (excluding high income)',
     'Middle East & North Africa (IDA & IBRD countries)',
     'Central Europe and the Baltics',
     'Pre-demographic dividend',
     'IDA only',
     'Least developed countries: UN classification',
     'IDA blend',
     'Fragile and conflict affected situations',
     'Heavily indebted poor countries (HIPC)',
     'Low income',
     'Small states',
     'Other small states',
     'Not classified',
     'Caribbean small states',
     'Pacific island small states']
    
    if country not in non_countries:
        data_array = np.array(data, ndmin=2)
        data_array.reshape(1, 63)
        df = pd.DataFrame(data_array, columns=colnames).replace('', np.nan)
        try:
            df.drop(['\r\n', 'Indicator Name', 'Indicator Code'], inplace=True, axis=1)
        except:
            pass

        # Reshape the data sets so that they are in long format
        df_melt = df.melt(id_vars=['Country Name', 'Country Code'], 
                            var_name='year', 
                            value_name='gdp')
        
        results = []
        for index, row in df_melt.iterrows():
            country, countrycode, year, gdp = row
            if str(gdp) != 'nan':
                results.append([country, countrycode, year, gdp])
        return results

# %%
# TODO: fill out the code wherever you find a TODO in this cell

def load_indicator_data(results):
    conn = sqlite3.connect('worldbank.db')
    cur = conn.cursor()
    if results:
        for result in results:
            countryname, countrycode, year, gdp = result

            sql_string = 'INSERT INTO gdp (countryname, countrycode, year, gdp) VALUES ("{}", "{}", {}, {});'.format(countryname, countrycode, year, gdp)

            # connect to database and execute query
            try:
                cur.execute(sql_string)
            except Exception as e:
                print('error occurred:', e, result)
            
    conn.commit()
    conn.close()
    
    return None

# %%
# Execute this code cell to run the ETL pipeline
# You do not need to change anything in this cell
with open('gdp_data.csv') as f:
    for line in extract_lines(f):
        data = line.split(',')
        if len(data) == 63:
            if data[0] == '"Country Name"':
                colnames = []
                # get rid of quote marks
                for i, datum in enumerate(data):
                    colnames.append(datum.replace('"',''))
            else:
                # transform and load the line of indicator data
                results = transform_indicator_data(data, colnames)
                load_indicator_data(results)
# Out:
# error occurred: near "Name": syntax error ['Aruba', 'ABW', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Aruba', 'ABW', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Aruba', 'ABW', '\n', '\n']
# error occurred: near "Name": syntax error ['Afghanistan', 'AFG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Afghanistan', 'AFG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Afghanistan', 'AFG', '\n', '\n']
# error occurred: near "Name": syntax error ['Angola', 'AGO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Angola', 'AGO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Angola', 'AGO', '\n', '\n']
# error occurred: near "Name": syntax error ['Albania', 'ALB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Albania', 'ALB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Albania', 'ALB', '\n', '\n']
# error occurred: near "Name": syntax error ['Andorra', 'AND', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Andorra', 'AND', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Andorra', 'AND', '\n', '\n']
# error occurred: near "Name": syntax error ['United Arab Emirates', 'ARE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['United Arab Emirates', 'ARE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['United Arab Emirates', 'ARE', '\n', '\n']
# error occurred: near "Name": syntax error ['Argentina', 'ARG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Argentina', 'ARG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Argentina', 'ARG', '\n', '\n']
# error occurred: near "Name": syntax error ['Armenia', 'ARM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Armenia', 'ARM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Armenia', 'ARM', '\n', '\n']
# error occurred: near "Name": syntax error ['American Samoa', 'ASM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['American Samoa', 'ASM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['American Samoa', 'ASM', '\n', '\n']
# error occurred: near "Name": syntax error ['Antigua and Barbuda', 'ATG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Antigua and Barbuda', 'ATG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Antigua and Barbuda', 'ATG', '\n', '\n']
# error occurred: near "Name": syntax error ['Australia', 'AUS', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Australia', 'AUS', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Australia', 'AUS', '\n', '\n']
# error occurred: near "Name": syntax error ['Austria', 'AUT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Austria', 'AUT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Austria', 'AUT', '\n', '\n']
# error occurred: near "Name": syntax error ['Azerbaijan', 'AZE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Azerbaijan', 'AZE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Azerbaijan', 'AZE', '\n', '\n']
# error occurred: near "Name": syntax error ['Burundi', 'BDI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Burundi', 'BDI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Burundi', 'BDI', '\n', '\n']
# error occurred: near "Name": syntax error ['Belgium', 'BEL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Belgium', 'BEL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Belgium', 'BEL', '\n', '\n']
# error occurred: near "Name": syntax error ['Benin', 'BEN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Benin', 'BEN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Benin', 'BEN', '\n', '\n']
# error occurred: near "Name": syntax error ['Burkina Faso', 'BFA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Burkina Faso', 'BFA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Burkina Faso', 'BFA', '\n', '\n']
# error occurred: near "Name": syntax error ['Bangladesh', 'BGD', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bangladesh', 'BGD', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bangladesh', 'BGD', '\n', '\n']
# error occurred: near "Name": syntax error ['Bulgaria', 'BGR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bulgaria', 'BGR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bulgaria', 'BGR', '\n', '\n']
# error occurred: near "Name": syntax error ['Bahrain', 'BHR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bahrain', 'BHR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bahrain', 'BHR', '\n', '\n']
# error occurred: near "Name": syntax error ['Bosnia and Herzegovina', 'BIH', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bosnia and Herzegovina', 'BIH', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bosnia and Herzegovina', 'BIH', '\n', '\n']
# error occurred: near "Name": syntax error ['Belarus', 'BLR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Belarus', 'BLR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Belarus', 'BLR', '\n', '\n']
# error occurred: near "Name": syntax error ['Belize', 'BLZ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Belize', 'BLZ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Belize', 'BLZ', '\n', '\n']
# error occurred: near "Name": syntax error ['Bermuda', 'BMU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bermuda', 'BMU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bermuda', 'BMU', '\n', '\n']
# error occurred: near "Name": syntax error ['Bolivia', 'BOL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bolivia', 'BOL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bolivia', 'BOL', '\n', '\n']
# error occurred: near "Name": syntax error ['Brazil', 'BRA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Brazil', 'BRA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Brazil', 'BRA', '\n', '\n']
# error occurred: near "Name": syntax error ['Barbados', 'BRB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Barbados', 'BRB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Barbados', 'BRB', '\n', '\n']
# error occurred: near "Name": syntax error ['Brunei Darussalam', 'BRN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Brunei Darussalam', 'BRN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Brunei Darussalam', 'BRN', '\n', '\n']
# error occurred: near "Name": syntax error ['Bhutan', 'BTN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Bhutan', 'BTN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Bhutan', 'BTN', '\n', '\n']
# error occurred: near "Name": syntax error ['Botswana', 'BWA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Botswana', 'BWA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Botswana', 'BWA', '\n', '\n']
# error occurred: near "Name": syntax error ['Central African Republic', 'CAF', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Central African Republic', 'CAF', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Central African Republic', 'CAF', '\n', '\n']
# error occurred: near "Name": syntax error ['Canada', 'CAN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Canada', 'CAN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Canada', 'CAN', '\n', '\n']
# error occurred: near "Name": syntax error ['Switzerland', 'CHE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Switzerland', 'CHE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Switzerland', 'CHE', '\n', '\n']
# error occurred: near "Name": syntax error ['Channel Islands', 'CHI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Channel Islands', 'CHI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Channel Islands', 'CHI', '\n', '\n']
# error occurred: near "Name": syntax error ['Chile', 'CHL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Chile', 'CHL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Chile', 'CHL', '\n', '\n']
# error occurred: near "Name": syntax error ['China', 'CHN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['China', 'CHN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['China', 'CHN', '\n', '\n']
# error occurred: near "Name": syntax error ["Cote d'Ivoire", 'CIV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ["Cote d'Ivoire", 'CIV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ["Cote d'Ivoire", 'CIV', '\n', '\n']
# error occurred: near "Name": syntax error ['Cameroon', 'CMR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cameroon', 'CMR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cameroon', 'CMR', '\n', '\n']
# error occurred: near "Name": syntax error ['Colombia', 'COL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Colombia', 'COL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Colombia', 'COL', '\n', '\n']
# error occurred: near "Name": syntax error ['Comoros', 'COM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Comoros', 'COM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Comoros', 'COM', '\n', '\n']
# error occurred: near "Name": syntax error ['Cabo Verde', 'CPV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cabo Verde', 'CPV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cabo Verde', 'CPV', '\n', '\n']
# error occurred: near "Name": syntax error ['Costa Rica', 'CRI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Costa Rica', 'CRI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Costa Rica', 'CRI', '\n', '\n']
# error occurred: near "Name": syntax error ['Cuba', 'CUB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cuba', 'CUB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cuba', 'CUB', '\n', '\n']
# error occurred: near "Name": syntax error ['Curacao', 'CUW', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Curacao', 'CUW', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Curacao', 'CUW', '\n', '\n']
# error occurred: near "Name": syntax error ['Cayman Islands', 'CYM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cayman Islands', 'CYM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cayman Islands', 'CYM', '\n', '\n']
# error occurred: near "Name": syntax error ['Cyprus', 'CYP', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cyprus', 'CYP', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cyprus', 'CYP', '\n', '\n']
# error occurred: near "Name": syntax error ['Czech Republic', 'CZE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Czech Republic', 'CZE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Czech Republic', 'CZE', '\n', '\n']
# error occurred: near "Name": syntax error ['Germany', 'DEU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Germany', 'DEU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Germany', 'DEU', '\n', '\n']
# error occurred: near "Name": syntax error ['Djibouti', 'DJI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Djibouti', 'DJI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Djibouti', 'DJI', '\n', '\n']
# error occurred: near "Name": syntax error ['Dominica', 'DMA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Dominica', 'DMA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Dominica', 'DMA', '\n', '\n']
# error occurred: near "Name": syntax error ['Denmark', 'DNK', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Denmark', 'DNK', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Denmark', 'DNK', '\n', '\n']
# error occurred: near "Name": syntax error ['Dominican Republic', 'DOM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Dominican Republic', 'DOM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Dominican Republic', 'DOM', '\n', '\n']
# error occurred: near "Name": syntax error ['Algeria', 'DZA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Algeria', 'DZA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Algeria', 'DZA', '\n', '\n']
# error occurred: near "Name": syntax error ['Ecuador', 'ECU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Ecuador', 'ECU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Ecuador', 'ECU', '\n', '\n']
# error occurred: near "Name": syntax error ['Eritrea', 'ERI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Eritrea', 'ERI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Eritrea', 'ERI', '\n', '\n']
# error occurred: near "Name": syntax error ['Spain', 'ESP', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Spain', 'ESP', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Spain', 'ESP', '\n', '\n']
# error occurred: near "Name": syntax error ['Estonia', 'EST', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Estonia', 'EST', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Estonia', 'EST', '\n', '\n']
# error occurred: near "Name": syntax error ['Ethiopia', 'ETH', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Ethiopia', 'ETH', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Ethiopia', 'ETH', '\n', '\n']
# error occurred: near "Name": syntax error ['Finland', 'FIN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Finland', 'FIN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Finland', 'FIN', '\n', '\n']
# error occurred: near "Name": syntax error ['Fiji', 'FJI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Fiji', 'FJI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Fiji', 'FJI', '\n', '\n']
# error occurred: near "Name": syntax error ['France', 'FRA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['France', 'FRA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['France', 'FRA', '\n', '\n']
# error occurred: near "Name": syntax error ['Faroe Islands', 'FRO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Faroe Islands', 'FRO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Faroe Islands', 'FRO', '\n', '\n']
# error occurred: near "Name": syntax error ['Gabon', 'GAB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Gabon', 'GAB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Gabon', 'GAB', '\n', '\n']
# error occurred: near "Name": syntax error ['United Kingdom', 'GBR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['United Kingdom', 'GBR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['United Kingdom', 'GBR', '\n', '\n']
# error occurred: near "Name": syntax error ['Georgia', 'GEO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Georgia', 'GEO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Georgia', 'GEO', '\n', '\n']
# error occurred: near "Name": syntax error ['Ghana', 'GHA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Ghana', 'GHA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Ghana', 'GHA', '\n', '\n']
# error occurred: near "Name": syntax error ['Gibraltar', 'GIB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Gibraltar', 'GIB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Gibraltar', 'GIB', '\n', '\n']
# error occurred: near "Name": syntax error ['Guinea', 'GIN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Guinea', 'GIN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Guinea', 'GIN', '\n', '\n']
# error occurred: near "Name": syntax error ['Guinea-Bissau', 'GNB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Guinea-Bissau', 'GNB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Guinea-Bissau', 'GNB', '\n', '\n']
# error occurred: near "Name": syntax error ['Equatorial Guinea', 'GNQ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Equatorial Guinea', 'GNQ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Equatorial Guinea', 'GNQ', '\n', '\n']
# error occurred: near "Name": syntax error ['Greece', 'GRC', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Greece', 'GRC', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Greece', 'GRC', '\n', '\n']
# error occurred: near "Name": syntax error ['Grenada', 'GRD', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Grenada', 'GRD', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Grenada', 'GRD', '\n', '\n']
# error occurred: near "Name": syntax error ['Greenland', 'GRL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Greenland', 'GRL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Greenland', 'GRL', '\n', '\n']
# error occurred: near "Name": syntax error ['Guatemala', 'GTM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Guatemala', 'GTM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Guatemala', 'GTM', '\n', '\n']
# error occurred: near "Name": syntax error ['Guam', 'GUM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Guam', 'GUM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Guam', 'GUM', '\n', '\n']
# error occurred: near "Name": syntax error ['Guyana', 'GUY', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Guyana', 'GUY', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Guyana', 'GUY', '\n', '\n']
# error occurred: near "Name": syntax error ['Honduras', 'HND', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Honduras', 'HND', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Honduras', 'HND', '\n', '\n']
# error occurred: near "Name": syntax error ['Croatia', 'HRV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Croatia', 'HRV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Croatia', 'HRV', '\n', '\n']
# error occurred: near "Name": syntax error ['Haiti', 'HTI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Haiti', 'HTI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Haiti', 'HTI', '\n', '\n']
# error occurred: near "Name": syntax error ['Hungary', 'HUN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Hungary', 'HUN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Hungary', 'HUN', '\n', '\n']
# error occurred: near "Name": syntax error ['Indonesia', 'IDN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Indonesia', 'IDN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Indonesia', 'IDN', '\n', '\n']
# error occurred: near "Name": syntax error ['Isle of Man', 'IMN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Isle of Man', 'IMN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Isle of Man', 'IMN', '\n', '\n']
# error occurred: near "Name": syntax error ['India', 'IND', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['India', 'IND', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['India', 'IND', '\n', '\n']
# error occurred: near "Name": syntax error ['Ireland', 'IRL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Ireland', 'IRL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Ireland', 'IRL', '\n', '\n']
# error occurred: near "Name": syntax error ['Iraq', 'IRQ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Iraq', 'IRQ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Iraq', 'IRQ', '\n', '\n']
# error occurred: near "Name": syntax error ['Iceland', 'ISL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Iceland', 'ISL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Iceland', 'ISL', '\n', '\n']
# error occurred: near "Name": syntax error ['Israel', 'ISR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Israel', 'ISR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Israel', 'ISR', '\n', '\n']
# error occurred: near "Name": syntax error ['Italy', 'ITA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Italy', 'ITA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Italy', 'ITA', '\n', '\n']
# error occurred: near "Name": syntax error ['Jamaica', 'JAM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Jamaica', 'JAM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Jamaica', 'JAM', '\n', '\n']
# error occurred: near "Name": syntax error ['Jordan', 'JOR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Jordan', 'JOR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Jordan', 'JOR', '\n', '\n']
# error occurred: near "Name": syntax error ['Japan', 'JPN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Japan', 'JPN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Japan', 'JPN', '\n', '\n']
# error occurred: near "Name": syntax error ['Kazakhstan', 'KAZ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kazakhstan', 'KAZ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kazakhstan', 'KAZ', '\n', '\n']
# error occurred: near "Name": syntax error ['Kenya', 'KEN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kenya', 'KEN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kenya', 'KEN', '\n', '\n']
# error occurred: near "Name": syntax error ['Kyrgyz Republic', 'KGZ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kyrgyz Republic', 'KGZ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kyrgyz Republic', 'KGZ', '\n', '\n']
# error occurred: near "Name": syntax error ['Cambodia', 'KHM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Cambodia', 'KHM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Cambodia', 'KHM', '\n', '\n']
# error occurred: near "Name": syntax error ['Kiribati', 'KIR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kiribati', 'KIR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kiribati', 'KIR', '\n', '\n']
# error occurred: near "Name": syntax error ['St. Kitts and Nevis', 'KNA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['St. Kitts and Nevis', 'KNA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['St. Kitts and Nevis', 'KNA', '\n', '\n']
# error occurred: near "Name": syntax error ['Kuwait', 'KWT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kuwait', 'KWT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kuwait', 'KWT', '\n', '\n']
# error occurred: near "Name": syntax error ['Lao PDR', 'LAO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Lao PDR', 'LAO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Lao PDR', 'LAO', '\n', '\n']
# error occurred: near "Name": syntax error ['Lebanon', 'LBN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Lebanon', 'LBN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Lebanon', 'LBN', '\n', '\n']
# error occurred: near "Name": syntax error ['Liberia', 'LBR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Liberia', 'LBR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Liberia', 'LBR', '\n', '\n']
# error occurred: near "Name": syntax error ['Libya', 'LBY', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Libya', 'LBY', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Libya', 'LBY', '\n', '\n']
# error occurred: near "Name": syntax error ['St. Lucia', 'LCA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['St. Lucia', 'LCA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['St. Lucia', 'LCA', '\n', '\n']
# error occurred: near "Name": syntax error ['Liechtenstein', 'LIE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Liechtenstein', 'LIE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Liechtenstein', 'LIE', '\n', '\n']
# error occurred: near "Name": syntax error ['Sri Lanka', 'LKA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sri Lanka', 'LKA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sri Lanka', 'LKA', '\n', '\n']
# error occurred: near "Name": syntax error ['Lesotho', 'LSO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Lesotho', 'LSO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Lesotho', 'LSO', '\n', '\n']
# error occurred: near "Name": syntax error ['Lithuania', 'LTU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Lithuania', 'LTU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Lithuania', 'LTU', '\n', '\n']
# error occurred: near "Name": syntax error ['Luxembourg', 'LUX', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Luxembourg', 'LUX', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Luxembourg', 'LUX', '\n', '\n']
# error occurred: near "Name": syntax error ['Latvia', 'LVA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Latvia', 'LVA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Latvia', 'LVA', '\n', '\n']
# error occurred: near "Name": syntax error ['St. Martin (French part)', 'MAF', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['St. Martin (French part)', 'MAF', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['St. Martin (French part)', 'MAF', '\n', '\n']
# error occurred: near "Name": syntax error ['Morocco', 'MAR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Morocco', 'MAR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Morocco', 'MAR', '\n', '\n']
# error occurred: near "Name": syntax error ['Monaco', 'MCO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Monaco', 'MCO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Monaco', 'MCO', '\n', '\n']
# error occurred: near "Name": syntax error ['Moldova', 'MDA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Moldova', 'MDA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Moldova', 'MDA', '\n', '\n']
# error occurred: near "Name": syntax error ['Madagascar', 'MDG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Madagascar', 'MDG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Madagascar', 'MDG', '\n', '\n']
# error occurred: near "Name": syntax error ['Maldives', 'MDV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Maldives', 'MDV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Maldives', 'MDV', '\n', '\n']
# error occurred: near "Name": syntax error ['Mexico', 'MEX', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mexico', 'MEX', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mexico', 'MEX', '\n', '\n']
# error occurred: near "Name": syntax error ['Marshall Islands', 'MHL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Marshall Islands', 'MHL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Marshall Islands', 'MHL', '\n', '\n']
# error occurred: near "Name": syntax error ['Mali', 'MLI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mali', 'MLI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mali', 'MLI', '\n', '\n']
# error occurred: near "Name": syntax error ['Malta', 'MLT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Malta', 'MLT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Malta', 'MLT', '\n', '\n']
# error occurred: near "Name": syntax error ['Myanmar', 'MMR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Myanmar', 'MMR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Myanmar', 'MMR', '\n', '\n']
# error occurred: near "Name": syntax error ['Montenegro', 'MNE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Montenegro', 'MNE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Montenegro', 'MNE', '\n', '\n']
# error occurred: near "Name": syntax error ['Mongolia', 'MNG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mongolia', 'MNG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mongolia', 'MNG', '\n', '\n']
# error occurred: near "Name": syntax error ['Northern Mariana Islands', 'MNP', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Northern Mariana Islands', 'MNP', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Northern Mariana Islands', 'MNP', '\n', '\n']
# error occurred: near "Name": syntax error ['Mozambique', 'MOZ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mozambique', 'MOZ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mozambique', 'MOZ', '\n', '\n']
# error occurred: near "Name": syntax error ['Mauritania', 'MRT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mauritania', 'MRT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mauritania', 'MRT', '\n', '\n']
# error occurred: near "Name": syntax error ['Mauritius', 'MUS', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Mauritius', 'MUS', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Mauritius', 'MUS', '\n', '\n']
# error occurred: near "Name": syntax error ['Malawi', 'MWI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Malawi', 'MWI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Malawi', 'MWI', '\n', '\n']
# error occurred: near "Name": syntax error ['Malaysia', 'MYS', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Malaysia', 'MYS', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Malaysia', 'MYS', '\n', '\n']
# error occurred: near "Name": syntax error ['Namibia', 'NAM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Namibia', 'NAM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Namibia', 'NAM', '\n', '\n']
# error occurred: near "Name": syntax error ['New Caledonia', 'NCL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['New Caledonia', 'NCL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['New Caledonia', 'NCL', '\n', '\n']
# error occurred: near "Name": syntax error ['Niger', 'NER', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Niger', 'NER', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Niger', 'NER', '\n', '\n']
# error occurred: near "Name": syntax error ['Nigeria', 'NGA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Nigeria', 'NGA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Nigeria', 'NGA', '\n', '\n']
# error occurred: near "Name": syntax error ['Nicaragua', 'NIC', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Nicaragua', 'NIC', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Nicaragua', 'NIC', '\n', '\n']
# error occurred: near "Name": syntax error ['Netherlands', 'NLD', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Netherlands', 'NLD', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Netherlands', 'NLD', '\n', '\n']
# error occurred: near "Name": syntax error ['Norway', 'NOR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Norway', 'NOR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Norway', 'NOR', '\n', '\n']
# error occurred: near "Name": syntax error ['Nepal', 'NPL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Nepal', 'NPL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Nepal', 'NPL', '\n', '\n']
# error occurred: near "Name": syntax error ['Nauru', 'NRU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Nauru', 'NRU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Nauru', 'NRU', '\n', '\n']
# error occurred: near "Name": syntax error ['New Zealand', 'NZL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['New Zealand', 'NZL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['New Zealand', 'NZL', '\n', '\n']
# error occurred: near "Name": syntax error ['Oman', 'OMN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Oman', 'OMN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Oman', 'OMN', '\n', '\n']
# error occurred: near "Name": syntax error ['Pakistan', 'PAK', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Pakistan', 'PAK', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Pakistan', 'PAK', '\n', '\n']
# error occurred: near "Name": syntax error ['Panama', 'PAN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Panama', 'PAN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Panama', 'PAN', '\n', '\n']
# error occurred: near "Name": syntax error ['Peru', 'PER', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Peru', 'PER', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Peru', 'PER', '\n', '\n']
# error occurred: near "Name": syntax error ['Philippines', 'PHL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Philippines', 'PHL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Philippines', 'PHL', '\n', '\n']
# error occurred: near "Name": syntax error ['Palau', 'PLW', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Palau', 'PLW', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Palau', 'PLW', '\n', '\n']
# error occurred: near "Name": syntax error ['Papua New Guinea', 'PNG', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Papua New Guinea', 'PNG', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Papua New Guinea', 'PNG', '\n', '\n']
# error occurred: near "Name": syntax error ['Poland', 'POL', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Poland', 'POL', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Poland', 'POL', '\n', '\n']
# error occurred: near "Name": syntax error ['Puerto Rico', 'PRI', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Puerto Rico', 'PRI', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Puerto Rico', 'PRI', '\n', '\n']
# error occurred: near "Name": syntax error ['Portugal', 'PRT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Portugal', 'PRT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Portugal', 'PRT', '\n', '\n']
# error occurred: near "Name": syntax error ['Paraguay', 'PRY', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Paraguay', 'PRY', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Paraguay', 'PRY', '\n', '\n']
# error occurred: near "Name": syntax error ['West Bank and Gaza', 'PSE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['West Bank and Gaza', 'PSE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['West Bank and Gaza', 'PSE', '\n', '\n']
# error occurred: near "Name": syntax error ['French Polynesia', 'PYF', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['French Polynesia', 'PYF', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['French Polynesia', 'PYF', '\n', '\n']
# error occurred: near "Name": syntax error ['Qatar', 'QAT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Qatar', 'QAT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Qatar', 'QAT', '\n', '\n']
# error occurred: near "Name": syntax error ['Romania', 'ROU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Romania', 'ROU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Romania', 'ROU', '\n', '\n']
# error occurred: near "Name": syntax error ['Russian Federation', 'RUS', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Russian Federation', 'RUS', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Russian Federation', 'RUS', '\n', '\n']
# error occurred: near "Name": syntax error ['Rwanda', 'RWA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Rwanda', 'RWA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Rwanda', 'RWA', '\n', '\n']
# error occurred: near "Name": syntax error ['Saudi Arabia', 'SAU', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Saudi Arabia', 'SAU', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Saudi Arabia', 'SAU', '\n', '\n']
# error occurred: near "Name": syntax error ['Sudan', 'SDN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sudan', 'SDN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sudan', 'SDN', '\n', '\n']
# error occurred: near "Name": syntax error ['Senegal', 'SEN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Senegal', 'SEN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Senegal', 'SEN', '\n', '\n']
# error occurred: near "Name": syntax error ['Singapore', 'SGP', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Singapore', 'SGP', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Singapore', 'SGP', '\n', '\n']
# error occurred: near "Name": syntax error ['Solomon Islands', 'SLB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Solomon Islands', 'SLB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Solomon Islands', 'SLB', '\n', '\n']
# error occurred: near "Name": syntax error ['Sierra Leone', 'SLE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sierra Leone', 'SLE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sierra Leone', 'SLE', '\n', '\n']
# error occurred: near "Name": syntax error ['El Salvador', 'SLV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['El Salvador', 'SLV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['El Salvador', 'SLV', '\n', '\n']
# error occurred: near "Name": syntax error ['San Marino', 'SMR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['San Marino', 'SMR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['San Marino', 'SMR', '\n', '\n']
# error occurred: near "Name": syntax error ['Somalia', 'SOM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Somalia', 'SOM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Somalia', 'SOM', '\n', '\n']
# error occurred: near "Name": syntax error ['Serbia', 'SRB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Serbia', 'SRB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Serbia', 'SRB', '\n', '\n']
# error occurred: near "Name": syntax error ['South Sudan', 'SSD', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['South Sudan', 'SSD', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['South Sudan', 'SSD', '\n', '\n']
# error occurred: near "Name": syntax error ['Sao Tome and Principe', 'STP', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sao Tome and Principe', 'STP', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sao Tome and Principe', 'STP', '\n', '\n']
# error occurred: near "Name": syntax error ['Suriname', 'SUR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Suriname', 'SUR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Suriname', 'SUR', '\n', '\n']
# error occurred: near "Name": syntax error ['Slovak Republic', 'SVK', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Slovak Republic', 'SVK', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Slovak Republic', 'SVK', '\n', '\n']
# error occurred: near "Name": syntax error ['Slovenia', 'SVN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Slovenia', 'SVN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Slovenia', 'SVN', '\n', '\n']
# error occurred: near "Name": syntax error ['Sweden', 'SWE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sweden', 'SWE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sweden', 'SWE', '\n', '\n']
# error occurred: near "Name": syntax error ['Swaziland', 'SWZ', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Swaziland', 'SWZ', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Swaziland', 'SWZ', '\n', '\n']
# error occurred: near "Name": syntax error ['Sint Maarten (Dutch part)', 'SXM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Sint Maarten (Dutch part)', 'SXM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Sint Maarten (Dutch part)', 'SXM', '\n', '\n']
# error occurred: near "Name": syntax error ['Seychelles', 'SYC', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Seychelles', 'SYC', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Seychelles', 'SYC', '\n', '\n']
# error occurred: near "Name": syntax error ['Syrian Arab Republic', 'SYR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Syrian Arab Republic', 'SYR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Syrian Arab Republic', 'SYR', '\n', '\n']
# error occurred: near "Name": syntax error ['Turks and Caicos Islands', 'TCA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Turks and Caicos Islands', 'TCA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Turks and Caicos Islands', 'TCA', '\n', '\n']
# error occurred: near "Name": syntax error ['Chad', 'TCD', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Chad', 'TCD', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Chad', 'TCD', '\n', '\n']
# error occurred: near "Name": syntax error ['Togo', 'TGO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Togo', 'TGO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Togo', 'TGO', '\n', '\n']
# error occurred: near "Name": syntax error ['Thailand', 'THA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Thailand', 'THA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Thailand', 'THA', '\n', '\n']
# error occurred: near "Name": syntax error ['Tajikistan', 'TJK', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Tajikistan', 'TJK', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Tajikistan', 'TJK', '\n', '\n']
# error occurred: near "Name": syntax error ['Turkmenistan', 'TKM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Turkmenistan', 'TKM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Turkmenistan', 'TKM', '\n', '\n']
# error occurred: near "Name": syntax error ['Timor-Leste', 'TLS', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Timor-Leste', 'TLS', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Timor-Leste', 'TLS', '\n', '\n']
# error occurred: near "Name": syntax error ['Tonga', 'TON', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Tonga', 'TON', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Tonga', 'TON', '\n', '\n']
# error occurred: near "Name": syntax error ['Trinidad and Tobago', 'TTO', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Trinidad and Tobago', 'TTO', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Trinidad and Tobago', 'TTO', '\n', '\n']
# error occurred: near "Name": syntax error ['Tunisia', 'TUN', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Tunisia', 'TUN', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Tunisia', 'TUN', '\n', '\n']
# error occurred: near "Name": syntax error ['Turkey', 'TUR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Turkey', 'TUR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Turkey', 'TUR', '\n', '\n']
# error occurred: near "Name": syntax error ['Tuvalu', 'TUV', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Tuvalu', 'TUV', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Tuvalu', 'TUV', '\n', '\n']
# error occurred: near "Name": syntax error ['Tanzania', 'TZA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Tanzania', 'TZA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Tanzania', 'TZA', '\n', '\n']
# error occurred: near "Name": syntax error ['Uganda', 'UGA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Uganda', 'UGA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Uganda', 'UGA', '\n', '\n']
# error occurred: near "Name": syntax error ['Ukraine', 'UKR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Ukraine', 'UKR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Ukraine', 'UKR', '\n', '\n']
# error occurred: near "Name": syntax error ['Uruguay', 'URY', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Uruguay', 'URY', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Uruguay', 'URY', '\n', '\n']
# error occurred: near "Name": syntax error ['United States', 'USA', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['United States', 'USA', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['United States', 'USA', '\n', '\n']
# error occurred: near "Name": syntax error ['Uzbekistan', 'UZB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Uzbekistan', 'UZB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Uzbekistan', 'UZB', '\n', '\n']
# error occurred: near "Name": syntax error ['St. Vincent and the Grenadines', 'VCT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['St. Vincent and the Grenadines', 'VCT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['St. Vincent and the Grenadines', 'VCT', '\n', '\n']
# error occurred: near "Name": syntax error ['British Virgin Islands', 'VGB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['British Virgin Islands', 'VGB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['British Virgin Islands', 'VGB', '\n', '\n']
# error occurred: near "Name": syntax error ['Virgin Islands (U.S.)', 'VIR', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Virgin Islands (U.S.)', 'VIR', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Virgin Islands (U.S.)', 'VIR', '\n', '\n']
# error occurred: near "Name": syntax error ['Vietnam', 'VNM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Vietnam', 'VNM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Vietnam', 'VNM', '\n', '\n']
# error occurred: near "Name": syntax error ['Vanuatu', 'VUT', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Vanuatu', 'VUT', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Vanuatu', 'VUT', '\n', '\n']
# error occurred: near "Name": syntax error ['Samoa', 'WSM', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Samoa', 'WSM', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Samoa', 'WSM', '\n', '\n']
# error occurred: near "Name": syntax error ['Kosovo', 'XKX', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Kosovo', 'XKX', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Kosovo', 'XKX', '\n', '\n']
# error occurred: near "Name": syntax error ['South Africa', 'ZAF', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['South Africa', 'ZAF', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['South Africa', 'ZAF', '\n', '\n']
# error occurred: near "Name": syntax error ['Zambia', 'ZMB', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Zambia', 'ZMB', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Zambia', 'ZMB', '\n', '\n']
# error occurred: near "Name": syntax error ['Zimbabwe', 'ZWE', 'Indicator Name', 'GDP (current US$)']
# error occurred: near "Code": syntax error ['Zimbabwe', 'ZWE', 'Indicator Code', 'NY.GDP.MKTP.CD']
# error occurred: near ",": syntax error ['Zimbabwe', 'ZWE', '\n', '\n']

# %%
# Execute this code cell to output the values in the gdp table
# You do not need to change anything in this cell

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# create the test table including project_id as a primary key
df = pd.read_sql("SELECT * FROM gdp", con=conn)

conn.commit()
conn.close()

df
# Out:
#      countryname countrycode  year           gdp
# 0          Aruba         ABW  1994  1.330168e+09
# 1          Aruba         ABW  1995  1.320670e+09
# 2          Aruba         ABW  1996  1.379888e+09
# 3          Aruba         ABW  1997  1.531844e+09
# 4          Aruba         ABW  1998  1.665363e+09
# ...          ...         ...   ...           ...
# 8709    Zimbabwe         ZWE  2013  1.545177e+10
# 8710    Zimbabwe         ZWE  2014  1.589105e+10
# 8711    Zimbabwe         ZWE  2015  1.630467e+10
# 8712    Zimbabwe         ZWE  2016  1.661996e+10
# 8713    Zimbabwe         ZWE  2017  1.784582e+10
#
# [8714 rows x 4 columns]

# %% [markdown]
# # Conclusion
#
# ETL Pipelines involve extracting data from one source, which in this case was a csv file, then transforming the data into a more usable form, and finally loading the data somewhere else.
#
# The purpose of ETL pipelines is to make data more usable and accessible.
